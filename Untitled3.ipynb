# %%
#IMPORTING DATA

# %%
import io
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.cluster import KMeans

df=pd.read_csv(r'C:\Users\AB\Desktop/cleaned_fintech_data.csv')

# %%
df
# Out:
#       Unnamed: 0                      created_at  \
# 0            0.0  Thu Jun 17 06:26:34 +0000 2021
# 1            1.0  Thu Jun 17 06:26:37 +0000 2021
# 2            2.0  Thu Jun 17 06:26:42 +0000 2021
# 3            3.0  Thu Jun 17 06:26:44 +0000 2021
# 4            4.0  Thu Jun 17 06:26:47 +0000 2021
# ...          ...                             ...
# 5616      2805.0  Thu Jun 17 10:21:02 +0000 2021
# 5617      2806.0  Thu Jun 17 10:21:03 +0000 2021
# 5618      2807.0  Thu Jun 17 10:21:08 +0000 2021
# 5619      2808.0  Thu Jun 17 10:21:09 +0000 2021
# 5620      2809.0  Thu Jun 17 10:21:10 +0000 2021
#
#                                                  source  \
# 0     <a href="https://mobile.twitter.com" rel="nofo...
# 1     <a href="http://twitter.com/download/android" ...
# 2     <a href="http://twitter.com/download/android" ...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/android" ...
# ...

# %%
#EXPLORING THE DATA

# %%
df.shape    #rows,columns
# Out:
# (5621, 21)

# %%
df.head(5)
# Out:
#    Unnamed: 0                      created_at  \
# 0         0.0  Thu Jun 17 06:26:34 +0000 2021
# 1         1.0  Thu Jun 17 06:26:37 +0000 2021
# 2         2.0  Thu Jun 17 06:26:42 +0000 2021
# 3         3.0  Thu Jun 17 06:26:44 +0000 2021
# 4         4.0  Thu Jun 17 06:26:47 +0000 2021
#
#                                               source  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                        original_text  \
# 0  Giving forth life is becoming a burden in Keny...
# 1  Teenmaar - 26cr\nPanja - 32.5cr\nGabbarsingh -...
# 2  Rei chintu 2013 lo Vachina Ad Nizam ne 2018 lo...
# 3  Today is World Day to Combat #Desertification ...
# 4  Hearing #GregHunt say he's confident vaccines ...
#
# ...

# %%
df.tail(5)
# Out:
#       Unnamed: 0                      created_at  \
# 5616      2805.0  Thu Jun 17 10:21:02 +0000 2021
# 5617      2806.0  Thu Jun 17 10:21:03 +0000 2021
# 5618      2807.0  Thu Jun 17 10:21:08 +0000 2021
# 5619      2808.0  Thu Jun 17 10:21:09 +0000 2021
# 5620      2809.0  Thu Jun 17 10:21:10 +0000 2021
#
#                                                  source  \
# 5616  <a href="https://mobile.twitter.com" rel="nofo...
# 5617  <a href="http://twitter.com/download/android" ...
# 5618  <a href="http://twitter.com/download/android" ...
# 5619  <a href="http://twitter.com/download/android" ...
# 5620  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                           original_text  \
# 5616  Lambie has voted AGAINST Medivac, Carbon tax, ...
# 5617  Idhi me bathuku \nMost Day1 Records In Nizam f...
# 5618  welkin moon giveaway bc i finally have money!\...
# 5619  Manam edi chesina \n\nDaaniki kuda elevation i...
# ...

# %%
df.count()  #Returns the number of non-null values in each DataFrame column
# Out:
# Unnamed: 0                5620
# created_at                5621
# source                    5621
# original_text             5621
# clean_text                5617
# sentiment                 5621
# polarity                  5621
# subjectivity              5621
# lang                      5621
# favorite_count            5621
# retweet_count             5621
# original_author           5621
# screen_count              5621
# followers_count           5621
# friends_count             5621
# possibly_sensitive         131
# hashtags                   813
# user_mentions             5621
# place                        1
# place_coord_boundaries    3603
# timestamp                 5621
# dtype: int64

# %%
#Data preparation

# %%
#Select columns that we use in mining the data from it.

# %%
se = DataFrame(df, columns=['polarity', 'subjectivity'])

# %%
se
# Out:
#                  polarity         subjectivity
# 0      0.3194444444444445   0.5305555555555556
# 1                     0.0                  0.0
# 2                     0.0                  0.0
# 3                    0.25                 0.65
# 4                     0.5   0.8333333333333334
# ...                   ...                  ...
# 5616  0.13636363636363635  0.45454545454545453
# 5617                  0.5                  0.5
# 5618  0.15416666666666667                  0.5
# 5619                  0.0                  0.0
# 5620                 0.13   0.4066666666666666
#
# [5621 rows x 2 columns]

# %%
#Drop null values from these columns that my misslead my conclusion

# %%
tweet=se.dropna()

# %%
tweet
# Out:
#                  polarity         subjectivity
# 0      0.3194444444444445   0.5305555555555556
# 1                     0.0                  0.0
# 2                     0.0                  0.0
# 3                    0.25                 0.65
# 4                     0.5   0.8333333333333334
# ...                   ...                  ...
# 5616  0.13636363636363635  0.45454545454545453
# 5617                  0.5                  0.5
# 5618  0.15416666666666667                  0.5
# 5619                  0.0                  0.0
# 5620                 0.13   0.4066666666666666
#
# [5621 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(tweet.polarity, # X-axis
                tweet.subjectivity,  # Y-axis
                s=100);


plt.title("Sentiment Analysis", fontsize = 20)
plt.xlabel('← Negative — — — — — — Positive →', fontsize=15)
plt.ylabel('← Facts — — — — — — — Opinions →', fontsize=15)
plt.tight_layout()
# Out:
# C:\Users\AB\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f, axs = plt.subplots(1, 2, figsize=(15,5))

sns.histplot(tweet.polarity, color="b", ax=axs[0])
axs[0].set_title("Tweet Polarity", fontsize = 20)
axs[0].set_xlabel('← Negative — — — — Positive →', fontsize=15)
sns.histplot(tweet.subjectivity, color="b", ax=axs[1])
axs[1].set_title("Tweet Subjectivity", fontsize = 20)
axs[1].set_xlabel('← Facts — — — — — Opinions →', fontsize=15)

plt.tight_layout()
